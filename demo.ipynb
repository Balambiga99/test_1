# %%
world = {
    "name": "IIITB",
    "programes":{"pgm1":"Research_Publications"},
    "description":"Represents the world of IIITB. All data published in this world are subject to the Big table rules.",
    "org_roles": {
        "role_id1" : "IIITB_Data_Officer",
        "role_id2": "IIITB_Data_Steward"
},
    
}

IIITB_Data_Officer = {
    "role_id" : "IIITB_RP_DOff1",
    "description": "Oversee the data sharing activities of IIITB ",
    "modalities": {
        "obligations" : [],
        "permissions" : [],
        "forbidden" : []
    }
}


research_publications = {
"description" : "gives details about the research publications programme in IIITB (i.e, world)",

"artifacts" : {
    "key": "artifact",
},

"requestor_roles": {
    "req_id1":"Data_requestor1"
    }
}

Data_Requestor = {
    "affiliation": "Infosys",
    "ID" : "Infy001",
    "Description": "Access IIITB artifacts under the Research publications programme",
    "description": "Oversee the data sharing activities of IIITB ",
    "modalities": {
        "obligations" : ["require_purpose"],
        "permissions" : ["read"],
        "forbidden" : ["share","download"]
    },
    "duration": "6 mths",
    "frequency" : "yearly" #frequency of what
}

artifact = {
    "description" : "describes the artifact",
    "owner"  : "IIITB",
    "id" : "IIITBRP_artif1",
    "access_type": "open", #only world level authentication required and the artifact can be viewed
    "allowed_role" : {
        "id" : "data_requestor"
    }
}
